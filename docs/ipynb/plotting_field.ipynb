# %% [markdown]
# # Tutorial: Plotting field slice

# %% [markdown]
# In this tutorial, we demonstrate different ways of setting the FD field values.
#
# Firstly, we import the required OOMMFField class.

# %%
from oommffield import OOMMFField

# %% [markdown]
# We create a three-dimansional vector field with domain that spans between:
#
# - minimum coordinate $c_\text{min} = (1, 1, 1)$ and
# - maximum coordinate $c_\text{max} = (10, 6, 9)$,
#
# with discretisation $d = (1, 1, 1)$.

# %%
cmin = (1, 1, 1)
cmax = (10, 6, 9)
d = (1, 1, 1)
dim = 3

# %% [markdown]
# After all the parameters are specified, we can create a field and give it a name.

# %%
field = OOMMFField(cmin, cmax, d, dim=dim, name='fdfield')

# %% [markdown]
# Now, we can set its value to be constant:
#
# $$f(x, y, z) = (1, 3, 5)$$

# %%
value = (1, 3, 5)
field.set(value)

# %% [markdown]
# After the field is set, we can plot its slice. Let's plot the slice perpendicular to the $x$ axis at the point $x=5$.

# %%
#PYTEST_VALIDATE_IGNORE_OUTPUT
# %matplotlib inline
fig = field.plot_slice('x', 5)
fig.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# More precisely, we plot a $y-z$ plane as it is shown on the plot's axes.
#
# If this plot is too large, its dimension can be changed by providing an additional argument in the plot_slice function: xsize. A vertical dimension will be set proportionally so that the plot accomodates the finite difference field domain. A default value for xsize is 10.

# %%
#PYTEST_VALIDATE_IGNORE_OUTPUT
fig = field.plot_slice('x', 5, xsize=5)
fig.show()

# %% [markdown]
# Now, we can set the field to be spatially varying, by providing a Python function defining its value:
#
# $$f(x, y, z) = (2xy, 2y + x, x + z)$$

# %%
def value(pos):
    x, y, z = pos
    
    fx = 2*x*y
    fy = 2*y + x
    fz = x + z
    
    return (fx, fy, fz)

field.set(value)

# %% [markdown]
# Now, we can plot the 'z' slice at point 5:

# %%
#PYTEST_VALIDATE_IGNORE_OUTPUT
fig = field.plot_slice('x', 3, xsize=7)
fig.show()

# %% [markdown]
# We can now see that $y-z$ slice is plotted, and colours correspond to the field's $x$-compoenent.
